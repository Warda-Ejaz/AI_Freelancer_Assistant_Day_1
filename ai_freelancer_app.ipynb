# %%
# !pkill -f streamlit

# %%
# %%writefile /content/ai_freelancer_app/app.py
import streamlit as st
st.title("📊 AI Freelancer Dashboard")
st.write("Welcome Warda")
st.write("Proposals: 24")
st.write("Cover Letters: 18")
st.write("AI Credits: 150")
st.success("Day 1 Complete!")
# Out:
# Overwriting /content/ai_freelancer_app/app.py

# %%
# !streamlit run /content/ai_freelancer_app/app.py --server.port 8501 --server.headless true &>/dev/null&
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦your url is: https://shy-brooms-battle.loca.lt
